# %% [markdown]
# <a href="https://colab.research.google.com/github/Karan18-hub/ELECTRONIC_DESIGN_AUTOMATION.../blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/raw.githubusercontent.com_krishnaik06_DiamondPricePrediction1_main_notebooks_data_gemstone.csv")
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.dtypes
# Out:
# id           int64
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
pd.unique(df['color'])
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
df = df.drop(['x'], axis=1)
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.61  4.77  14453

# %%
df = df.drop(['y'], axis=1)
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  4.77  14453

# %%
df = df.drop(['z'], axis=1)
df.head()
# Out:
#    id  carat        cut color clarity  depth  table  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  14453

# %%
df = df.drop(['table'], axis=1)
df.head()
# Out:
#    id  carat        cut color clarity  depth  price
# 0   0   1.52    Premium     F     VS2   62.2  13619
# 1   1   2.03  Very Good     J     SI2   62.0  13387
# 2   2   0.70      Ideal     G     VS1   61.2   2772
# 3   3   0.32      Ideal     G     VS1   61.6    666
# 4   4   1.70    Premium     G     VS2   62.6  14453

# %%
df.shape
# Out:
# (39318, 7)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 7)

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    id  carat        cut color clarity  depth  price
# 0   0   1.52    Premium     F     VS2   62.2  13619
# 1   1   2.03  Very Good     J     SI2   62.0  13387
# 2   2   0.70      Ideal     G     VS1   61.2   2772
# 3   3   0.32      Ideal     G     VS1   61.6    666
# 4   4   1.70    Premium     G     VS2   62.6  14453

# %%
print(df.isnull().sum())
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# price      0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,annot=True)
# Out:
# <ipython-input-16-845a837895fd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['carat'],y=df['price'])
# Out:
# <Axes: xlabel='carat', ylabel='price'>
